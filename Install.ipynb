# %%
pip install tensorflow
# Out:
# ...
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/e4/14/d795bb156f8cc10eb1dcfe1332b7dbb8405b634688980aa9be8f885cc888/tensorflow-2.16.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.16.1 from https://files.pythonhosted.org/packages/e0/36/6278e4e7e69a90c00e0f82944d8f2713dd85a69d1add455d9e50446837ab/tensorflow_intel-2.16.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for astunparse>=1.6.0 from https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl.metadata
# ...

# %%
pip install flask_monitoringdashboard
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'

# %%
pip install --upgrade flask_monitoringdashboard
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'

# %%
pip install flask-monitor
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for flask-monitor: filename=flask_monitor-0.2.6-py3-none-any.whl size=14748 sha256=93af68d784af3dc1da79bc2e8b0d2c12ba1e767a6ca0c8addccf631407116ed7
#   Stored in directory: c:\users\bbakouzou\appdata\local\pip\cache\wheels\5a\54\01\122b28e5212814aedcb4dbc94c8293bc9fc664c12434c53916
# Successfully built flask-monitor
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'

# %%
pip install Flask-Limiter
# Out:
# ...
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\bbakouzou\AppData\Local\anaconda3\Lib\site-packages\werkzeug-3.0.1.dist-info due to invalid metadata entry 'name'
#   Obtaining dependency information for Flask-Limiter from https://files.pythonhosted.org/packages/09/d3/f10e91728a0d33cce23e46eb05948dc38e959018cddf15103af0e08eeec6/Flask_Limiter-3.7.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for limits>=2.8 from https://files.pythonhosted.org/packages/88/a4/bc01e7945899bfa5c753a252d58a773b152102f6b763b4b00d3fc953ff85/limits-3.12.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for deprecated>=1.2 from https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl.metadata
# ...
